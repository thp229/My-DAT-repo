# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
train_path = "/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/class material/Unit 3/data/iowa_housing/train.csv"

# %%
test_path = "/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/class material/Unit 3/data/iowa_housing/test.csv"

# %%
train = pd.read_csv(train_path)

# %%
test = pd.read_csv(test_path)

# %%
def rmse(estimator, X, y):
    preds = estimator.predict(X)
    return np.sqrt(np.mean((preds - y)**2))

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
items_dict = {}

for items in train.columns:
    items_dict[str(items)] = train[str(items)].isnull().sum()

null_features = []
for k,v in items_dict.items():
    if v > 0:
        null_features.append(k)
print(null_features)
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.plot(kind="scatter", x ="GarageArea", y = "GrLivArea")
plt.show()

# %%
#break it up into CTS vs discrete variables 
for items in train.columns:
    print(items)
# Out:
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice

# %%
train["Fireplaces"].isnull().sum()
# Out:
# 0

# %%
train["SalePrice_ln"] = np.log(train["SalePrice"])

# %%
train.plot(kind = "scatter", x ="HalfBath" , y = "SalePrice_ln")

# %%
#train["sqft"] = train["GrLivArea"] + train["TotalBsmtSF"]

# %%
train[["BsmtFinSF1","BsmtFinSF2","BsmtUnfSF","TotalBsmtSF"]].head()
# Out:
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0         706           0        150          856
# 1         978           0        284         1262
# 2         486           0        434          920
# 3         216           0        540          756
# 4         655           0        490         1145

# %%
#train.drop("proportion", axis = 1, inplace = True)

# %%
train["total_bath"] = train["BsmtFullBath"] + train["BsmtHalfBath"] + train["FullBath"] + train["HalfBath"]

# %%
train.plot(kind = "scatter", x ="total_bath" , y = "SalePrice_ln")

# %%
train[["1stFlrSF","2ndFlrSF","TotalBsmtSF","LowQualFinSF","GrLivArea"]].head()
# Out:
#    1stFlrSF  2ndFlrSF  TotalBsmtSF  LowQualFinSF  GrLivArea
# 0       856       854          856             0       1710
# 1      1262         0         1262             0       1262
# 2       920       866          920             0       1786
# 3       961       756          756             0       1717
# 4      1145      1053         1145             0       2198

# %%
train[["BsmtFullBath","BsmtHalfBath","FullBath","HalfBath"]].head(100)
# Out:
#     BsmtFullBath  BsmtHalfBath  FullBath  HalfB