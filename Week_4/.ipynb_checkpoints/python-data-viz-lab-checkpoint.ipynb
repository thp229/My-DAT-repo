# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Guided Practice: Explore Python Data Visualization
#
# _Authors: Alexander Combs (New York City), Dave Yerrington (San Francisco), and Kevin Markham (Washington, D.C.)_
#
# ---
#
# In this guided practice lab you will use Pandas, Matplotlib, and Seaborn to create simple plots.
#
# We'll cover plotting line plots, scatter plots, bar plots, and histograms, and how to manipulate the style of your plots with Matplotlib.

# %% [markdown]
# ## Learning Objectives
#
# - **Practice** using different types of plots.
# - **Use** Pandas methods for plotting.
# - **Create** line plots, bar plots, histograms, and box plots.
# - **Know** when to use Seaborn or advanced Matplotlib

# %% [markdown]
# ### Pandas Plotting Documentation
#
# [Link to Documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html)

# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ### Create fake data for examples.

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %% [markdown]
# ### Load in data sets for visualization examples.
#
# The Boston data dictionary can be found [here](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names).

# %%
# Read in the Boston housing data.
housing_csv = "/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/projects/required/project-housing-data/data/boston_data.csv"
housing = pd.read_csv(housing_csv)

# Read in the drinks data.
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drinks_csv = "/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/class material/Unit 2/data/drinks.csv"
drinks = pd.read_csv(drinks_csv, header=0, names=drink_cols, na_filter=False)

# Read in the ufo data.
ufo = pd.read_csv("/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/class material/Unit 2/data/ufo.csv")
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 16              Los Angeles             NaN            NaN    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska             NaN           DISK    NE
# 21                      NaN             NaN            NaN    LA
# 22                      NaN             NaN          LIGHT    LA
# 23                Owensboro             NaN      RECTANGLE    KY
# 24               Wilderness             NaN           DISK    WV
# 25                San Diego             NaN          CIGAR    CA
# 26               Wilderness             NaN           DISK    WV
# 27                   Clovis             NaN           DISK    NM
# 28               Los Alamos             NaN           DISK    NM
# 29             Ft. Duschene             NaN           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin             NaN         CIRCLE    NJ
# 80514           New Bedford             NaN          LIGHT    MA
# 80515            Woodbridge             NaN       TRIANGLE    VA
# 80516              Glendale             NaN       CYLINDER    CA
# 80517               Laconia             NaN          CIGAR    NH
# 80518             Langhorne             NaN          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg             NaN          FLASH    PA
# 80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80534 2014-09-04 22:30:00  2014
# 80535 2014-09-04 22:30:00  2014
# 80536 2014-09-04 23:00:00  2014
# 80537 2014-09-04 23:20:00  2014
# 80538 2014-09-04 23:20:00  2014
# 80539 2014-09-05 01:14:00  2014
# 80540 2014-09-05 02:40:00  2014
# 80541 2014-09-05 03:43:00  2014
# 80542 2014-09-05 05:30:00  2014
#
# [80543 rows x 6 columns]

# %% [markdown]
# <a id="line-plots"></a>
# ## Line plots: Show the trend of a numerical variable over time
# ---
#
# - **Objective:** **Use** Pandas methods for plotting.
# - **Objective:** **Create** line plots, bar plots, histograms, and box plots.

# %%
# Count the number of ufo reports each year (and sort by year).
ufo.Year.value_counts().sort_index()  #note the use of the sort_index() function
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
# 1936       2
# 1937       2
# 1939       3
# 1941       2
# 1942       3
# 1943       5
# 1944       8
# 1945       9
# 1946       8
# 1947      41
# 1948       9
# 1949      19
# 1950      31
# 1951      21
# 1952      52
# 1953      36
# 1954      55
# 1955      33
# 1956      46
# 1957      78
# 1958      53
# 1959      57
# 1960      67
# 1961      50
# 1962      72
#         ...
# 1985     211
# 1986     186
# 1987     210
# 1988     232
# 1989     247
# 1990     237
# 1991     220
# 1992     245
# 1993     292
# 1994     406
# 1995    1344
# 1996     851
# 1997    1237
# 1998    1743
# 1999    2774
# 2000    2635
# 2001    2925
# 2002    2933
# 2003    3507
# 2004    3850
# 2005    3787
# 2006    3445
# 2007    4058
# 2008    4655
# 2009    4251
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, Length: 82, dtype: int64

# %%
# Compare with line plot -- UFO sightings by year. (Ordering by year makes sense.)
ufo.Year.value_counts().sort_index().plot();

#note that the .plot() method will default to a line-chart if a kind is not specified!

# %%
drinks["continent"].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# COMMON MISTAKE: Don't use a line plot when the x-axis cannot be ordered sensically!

# For example, ordering by continent below shows a trend where no exists ... 
#    it would be just as valid to plot the continents in any order.

# So, a line plot is the wrong type of plot for this data.
# Always think about what you're plotting and if it makes sense.

drinks.continent.value_counts().plot();

# %% [markdown]
# **Important:** A line plot is the wrong type of plot for this data. Any set of countries can be rearranged misleadingly to illustrate a negative trend, as we did here. Due to this, it would be more appropriate to represent this data using a bar plot, which does not imply a trend based on order.

# %%
# Plot the same data as a (horizontal) bar plot -- a much better choice!
drinks.continent.value_counts().plot(kind='barh');

# %% [markdown]
# ### How to change the color of a plot

# %%
df['col1'].plot(color='crimson', figsize=(16,8));

# %% [markdown]
# ### How to change the style of individual lines

# %%
# : - dotted line, v - triangle_down
# r - red, b - blue
df[['col1', 'col4']].plot(figsize=(15,7), style={'col1': ':r', 'col4': 'vb'});

# %% [markdown]
# ### Challenge: Create a line plot of `ZN` and `INDUS` in the housing data.
#
# - For `ZN`, use a solid green line. For `INDUS`, use a blue dashed line.
# - Change the figure size to a width of 12 and height of 8.
# - Change the style sheet to something you find [here](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html).

# %%
housing[[" ZN ", "INDUS "]].plot(figsize=(12,8), style = {" ZN ":"g", "INDUS ":":b"})

# %% [markdown]
# <a id="bar-plots"></a>
# ## Bar Plots: Show a numerical comparison across different categories
# ---

# %%
# Calculate the mean alcohol amounts for each continent.
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
# Side-by-side bar plots
drinks.groupby('continent').mean().plot(kind='bar'); #coming the .groupby() method with the .plot() function

# %%
# Sort the continent x-axis by a particular column.
drinks.groupby('continent').mean().sort_values('beer').plot(kind='bar');

# %%
# Stacked bar plot (with the liters comparison removed!)
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True);

# %% [markdown]
# ### Challenge: Create a bar chart using `col1` and `col2`.
#
# - Give the plot a title of your choosing.

# %%
df[["col1","col2"]].plot(kind="bar", title="My Bar Chart")

# %% [markdown]
# - Do the same thing but with horizontal bars.

# %%
df[["col1","col2"]].plot(kind="barh", title = "My Horizontal Bar Chart")

# %% [markdown]
# ### Stacked works on horizontal bar charts too

# %%
df.plot(kind='barh', stacked=True, figsize=(16,8));

# %% [markdown]
# <a id="histograms"></a>
# ## Histograms: Show the distribution of a numerical variable
# ---

# %% [markdown]
# ### Challenge: Create a histogram with pandas for using `MEDV` in the housing data.
# - Set the bins to 20.

# %%
# your code here
housing["MEDV"].hist(bins = 20)

# %% [markdown]
# <a id="grouped-histograms"></a>
# ### Challenge:
#  - Create a histogram for the beer column, for each continent
#  - Share the x and y axis
#  - Make the layout 2x3

# %%
# your code here
drinks.hist(column = "beer", by = "continent", layout = (2,3), figsize = (12,8), sharex = True, sharey = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b198da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b3b19e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b4cf470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b4f4c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b526470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b5264a8>]],
#       dtype=object)

# %% [markdown]
# <a id="scatter-plots"></a>
# ## Scatter plots: Show the relationship between two numerical variables
# ---

# %%
# Compare with scatter plot.
drinks.plot(kind='scatter', x='beer', y='wine');

# %%
# Add transparency (great for plotting several graphs on top of each other, or for illustrating density!).
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.3);

# %%
# the s argument can be used to set the size of your marks
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.3, s=75);

# %% [markdown]
# ### Challenge: Show the Relationship Between Price & Lstat in the Housing Data With A Scatter Plot
#  - set the color to something that you like
#  - set the figsize to (15, 7)
#  - give it a title
#  - use the 's' argument to set the size of your

# %%
# Your Code Here
#housing[["MEDV", "LSTAT"]].head()

housing.plot("LSTAT", "MEDV", kind ="scatter", figsize = (15,7), title = "Relationship Between Price and Lstat", alpha = "0.3", s=75)

# %% [markdown]
# ### Other Items You Can Do.......

# %%
# Saving a plot to a file
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings');
plt.xlabel('Beer Servings');
plt.ylabel('Frequency');
plt.savefig('beer_histogram.png');    # Save to file!

# %%
# List available plot styles
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# Change to a different style.
plt.style.use('ggplot')

# %% [markdown]
# <a id="summary"></a>
# ### Summary
#
# In this lesson, we showed examples how to create a variety of plots using Pandas and Matplotlib. We also showed how to use each plot to effectively display data.
#
# Do not be concerned if you do not remember everything — this will come with practice! Although there are many plot styles, many similarities exist between how each plot is drawn. For example, they have most parameters in common, and the same Matplotlib functions are used to modify the plot area.
#
# We looked at:
# - Line plots
# - Bar plots
# - Histograms
# - Scatterplots
