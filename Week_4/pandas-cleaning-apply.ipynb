# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
# load in the appropriate path to the file you want to load in
rockfile = "/Users/theodoreplotkin/desktop/postmalone/GA_Data_Science/DAT-06-24/class material/Unit 2/data/rock.csv"

# %%
# Load the data.
rock = pd.read_csv(rockfile)

# %%
# Look at the information regarding its columns.
rock.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
rock.columns
# Out:
# Index(['Song Clean', 'ARTIST CLEAN', 'Release Year', 'COMBINED', 'First?',
#        'Year?', 'PlayCount', 'F*G'],
#       dtype='object')

# %%
rock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song         2230 non-null object
# Artist       2230 non-null object
# Release      2230 non-null object
# Combined     2230 non-null object
# First        2230 non-null int64
# Year         2230 non-null int64
# Playcount    2230 non-null int64
# F*G          2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
# Change the column names when loading the '.csv':

col_names = ["Song", "Artist", "Release", "Combined", "First", "Year", "Playcount", "F*G"]

rock = pd.read_csv(rockfile, header = 0, names = col_names)
rock.head()
# Out:
#                      Song       Artist Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 Combined  First  Year  Playcount  F*G
# 0        Caught Up in You by .38 Special      1     1         82   82
# 1            Fantasy Girl by .38 Special      1     0          3    0
# 2         Hold On Loosely by .38 Special      1     1         85   85
# 3  Rockin' Into the Night by .38 Special      1     1         18   18
# 4              Art For Arts Sake by 10cc      1     1          1    1

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
rock = pd.read_csv(rockfile)
rock.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
#recall the .rename method takes a dictionary as input 
rock.rename(columns={"Song Clean":"Song",
                     "ARTIST CLEAN":"Artist",
                     "Release Year":"Release", 
                     "COMBINED":"Combined",
                     "First?":"First",
                     "Year?":"Year",
                     "PlayCount":"Playcount",
                     "F*G":"F*G"}, inplace = True)
rock.head()
# Out:
#                      Song       Artist Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 Combined  First  Year  Play Count  F*G
# 0        Caught Up in You by .38 Special      1     1          82   82
# 1            Fantasy Girl by .38 Special      1     0           3    0
# 2         Hold On Loosely by .38 Special      1     1          85   85
# 3  Rockin' Into the Night by .38 Special      1     1          18   18
# 4              Art For Arts Sake by 10cc      1     1           1    1

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.

# %%
rock = pd.read_csv(rockfile)
rock.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
col_names = ["Song", "Artist", "Release", "Combined", "First", "Year", "Playcount", "F*G"]

rock.columns = col_names
rock.head()
# Out:
#                      Song       Artist Release  \
# 0        Caught Up in You  .38 Special    1982
# 1            Fantasy Girl  .38 Special     NaN
# 2         Hold On Loosely  .38 Special    1981
# 3  Rockin' Into the Night  .38 Special    1980
# 4       Art For Arts Sake         10cc    1975
#
#                                 Combined  First  Year  Playcount  F*G
# 0        Caught Up in You by .38 Special      1     1         82   82
# 1            Fantasy Girl by .38 Special      1     0          3    0
# 2         Hold On Loosely by .38 Special      1     1         85   85
# 3  Rockin' Into the Night by .38 Special      1     1         18   18
# 4              Art For Arts Sake by 10cc      1     1          1    1

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
# Show records where df['release'] is null
rock["Release"].isnull().head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Release, dtype: bool

# %% [markdown]
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
rock.Release.fillna(value = 0, inplace = True)
#note we include the inplace = True to overwrite the changes to the dataframe
rock.head(100)
# Out:
#                                    Song                Artist Release  \
# 0                      Caught Up in You           .38 Special    1982
# 1                          Fantasy Girl           .38 Special       0
# 2                       Hold On Loosely           .38 Special    1981
# 3                Rockin' Into the Night           .38 Special    1980
# 4                     Art For Arts Sake                  10cc    1975
# 5                            Kryptonite          3 Doors Down    2000
# 6                                 Loser          3 Doors Down    2000
# 7                         When I'm Gone          3 Doors Down    2002
# 8                            What's Up?         4 Non Blondes    1992
# 9                            Take On Me                  a-ha    1985
# 10                Baby, Please Don't Go                 AC/DC       0
# 11                        Back In Black                 AC/DC    1980
# 12                              Big Gun                 AC/DC    1993
# 13               CAN'T STOP ROCK'N'ROLL                 AC/DC       0
# 14          Dirty Deeds Done Dirt Cheap                 AC/DC    1976
# 15              For Those About To Rock                 AC/DC    1981
# 16                     Girls Got Rhythm                 AC/DC       0
# 17                       Hard As A Rock                 AC/DC    1995
# 18                   Have a Drink On Me                 AC/DC    1980
# 19                          Hells Bells                 AC/DC    1980
# 20                      Highway To Hell                 AC/DC    1979
# 21           It's A Long Way To The Top                 AC/DC    1975
# 22                            Jailbreak                 AC/DC    1984
# 23                    Let There Be Rock                 AC/DC    1977
# 24                      Let's Get It Up                 AC/DC       0
# 25                            Live Wire                 AC/DC       0
# 26                           Moneytalks                 AC/DC       0
# 27                        Night Prowler                 AC/DC    1979
# 28  Rock and Roll Ain't Noise Pollution                 AC/DC    1980
# 29                      Shoot To Thrill                 AC/DC       0
# ..                                  ...                   ...     ...
# 70                        What It Takes             Aerosmith    1989
# 71                    You See Me Crying             Aerosmith       0
# 72                    Hand In My Pocket     Alanis Morissette    1995
# 73                      You Oughta Know     Alanis Morissette    1995
# 74                         Black Velvet         Alannah Myles    1989
# 75                              Fantasy             Aldo Nova       0
# 76                          BE MY LOVER          Alice Cooper       0
# 77                Billion Dollar Babies          Alice Cooper    1973
# 78                             Eighteen          Alice Cooper    1971
# 79                              Elected          Alice Cooper    1973
# 80                        House Of Fire          Alice Cooper       0
# 81                         I'm Eighteen          Alice Cooper    1971
# 82                 No More Mr. Nice Guy          Alice Cooper    1973
# 83                         School's Out          Alice Cooper    1972
# 84                      Under My Wheels          Alice Cooper    1971
# 85              Welcome To My Nightmare          Alice Cooper    1975
# 86                       Down in a Hole       Alice In Chains    1992
# 87                       Man In The Box       Alice In Chains    1990
# 88                           No Excuses       Alice In Chains    1994
# 89                              Rooster       Alice In Chains    1992
# 90                           Them Bones       Alice In Chains    1992
# 91                               Would?       Alice In Chains    1992
# 92           Ain't Wastin' Time No More  Allman Brothers Band    1972
# 93                             Blue Sky  Allman Brothers Band    1972
# 94                       Good Clean Fun  Allman Brothers Band    1990
# 95          In Memory Of Elizabeth Reed  Allman Brothers Band    1970
# 96                              Jessica  Allman Brothers Band    1973
# 97                              Melissa  Allman Brothers Band    1972
# 98                       Midnight Rider  Allman Brothers Band    1970
# 99                   No One to Run With  Allman Brothers Band    1994
#
#                                              Combined  First  Year  Playcount  \
# 0                     Caught Up in You by .38 Special      1     1         82
# 1                         Fantasy Girl by .38 Special      1     0          3
# 2                      Hold On Loosely by .38 Special      1     1         85
# 3               Rockin' Into the Night by .38 Special      1     1         18
# 4                           Art For Arts Sake by 10cc      1     1          1
# 5                          Kryptonite by 3 Doors Down      1     1         13
# 6                               Loser by 3 Doors Down      1     1          1
# 7                       When I'm Gone by 3 Doors Down      1     1          6
# 8                         What's Up? by 4 Non Blondes      1     1          3
# 9                                  Take On Me by a-ha      1     1          1
# 10                     Baby, Please Don't Go by AC/DC      1     0          1
# 11                             Back In Black by AC/DC      1     1         97
# 12                                   Big Gun by AC/DC      1     1          6
# 13                    CAN'T STOP ROCK'N'ROLL by AC/DC      1     0          5
# 14               Dirty Deeds Done Dirt Cheap by AC/DC      1     1         85
# 15                   For Those About To Rock by AC/DC      1     1         46
# 16                          Girls Got Rhythm by AC/DC      1     0         24
# 17                            Hard As A Rock by AC/DC      1     1          1
# 18                        Have a Drink On Me by AC/DC      1     1         39
# 19                               Hells Bells by AC/DC      1     1         74
# 20                           Highway To Hell by AC/DC      1     1         92
# 21                It's A Long Way To The Top by AC/DC      1     1         39
# 22                                 Jailbreak by AC/DC      1     1          1
# 23                         Let There Be Rock by AC/DC      1     1          3
# 24                           Let's Get It Up by AC/DC      1     0          4
# 25                                 Live Wire by AC/DC      1     0          2
# 26                                Moneytalks by AC/DC      1     0         20
# 27                             Night Prowler by AC/DC      1     1          1
# 28       Rock and Roll Ain't Noise Pollution by AC/DC      1     1         21
# 29                           Shoot To Thrill by AC/DC      1     0         45
# ..                                                ...    ...   ...        ...
# 70                         What It Takes by Aerosmith      1     1         31
# 71                     You See Me Crying by Aerosmith      1     0          1
# 72             Hand In My Pocket by Alanis Morissette      1     1          1
# 73               You Oughta Know by Alanis Morissette      1     1          6
# 74                      Black Velvet by Alannah Myles      1     1          1
# 75                               Fantasy by Aldo Nova      1     0          4
# 76                        BE MY LOVER by Alice Cooper      1     0          1
# 77              Billion Dollar Babies by Alice Cooper      1     1          2
# 78                           Eighteen by Alice Cooper      1     1          4
# 79                            Elected by Alice Cooper      1     1          1
# 80                      House Of Fire by Alice Cooper      1     0          1
# 81                       I'm Eighteen by Alice Cooper      1     1         24
# 82               No More Mr. Nice Guy by Alice Cooper      1     1         39
# 83                       School's Out by Alice Cooper      1     1         44
# 84                    Under My Wheels by Alice Cooper      1     1         18
# 85            Welcome To My Nightmare by Alice Cooper      1     1         10
# 86                  Down in a Hole by Alice In Chains      1     1          1
# 87                  Man In The Box by Alice In Chains      1     1         13
# 88                      No Excuses by Alice In Chains      1     1          2
# 89                         Rooster by Alice In Chains      1     1          2
# 90                      Them Bones by Alice In Chains      1     1          2
# 91                          Would? by Alice In Chains      1     1          2
# 92  Ain't Wastin' Time No More by Allman Brothers ...      1     1          1
# 93                   Blue Sky by Allman Brothers Band      1     1          1
# 94             Good Clean Fun by Allman Brothers Band      1     1          2
# 95  In Memory Of Elizabeth Reed by Allman Brothers...      1     1          1
# 96                    Jessica by Allman Brothers Band      1     1         12
# 97                    Melissa by Allman Brothers Band      1     1          6
# 98             Midnight Rider by Allman Brothers Band      1     1         21
# 99         No One to Run With by Allman Brothers Band      1     1          3
#
#     F*G
# 0    82
# 1     0
# 2    85
# 3    18
# 4     1
# 5    13
# 6     1
# 7     6
# 8     3
# 9     1
# 10    0
# 11   97
# 12    6
# 13    0
# 14   85
# 15   46
# 16    0
# 17    1
# 18   39
# 19   74
# 20   92
# 21   39
# 22    1
# 23    3
# 24    0
# 25    0
# 26    0
# 27    1
# 28   21
# 29    0
# ..  ...
# 70   31
# 71    0
# 72    1
# 73    6
# 74    1
# 75    0
# 76    0
# 77    2
# 78    4
# 79    1
# 80    0
# 81   24
# 82   39
# 83   44
# 84   18
# 85   10
# 86    1
# 87   13
# 88    2
# 89    2
# 90    2
# 91    2
# 92    1
# 93    1
# 94    2
# 95    1
# 96   12
# 97    6
# 98   21
# 99    3
#
# [100 rows x 8 columns]

# %%
#a useful tip for replacing NaNs in more than one column at a time

#the .select_dtypes() method, takes include = <np.some data type> as an argument 
cat_columns = rock.select_dtypes(include = np.object).columns.tolist()

# %%
rock[cat_columns] #would select only the columns which include categorical data
# Out:
#                                              Song         Artist Release  \
# 0                                Caught Up in You    .38 Special    1982
# 1                                    Fantasy Girl    .38 Special       0
# 2                                 Hold On Loosely    .38 Special    1981
# 3                          Rockin' Into the Night    .38 Special    1980
# 4                               Art For Arts Sake           10cc    1975
# 5                                      Kryptonite   3 Doors Down    2000
# 6                                           Loser   3 Doors Down    2000
# 7                                   When I'm Gone   3 Doors Down    2002
# 8                                      What's Up?  4 Non Blondes    1992
# 9                                      Take On Me           a-ha    1985
# 10                          Baby, Please Don't Go          AC/DC       0
# 11                                  Back In Black          AC/DC    1980
# 12                                        Big Gun          AC/DC    1993
# 13                         CAN'T STOP ROCK'N'ROLL          AC/DC       0
# 14                    Dirty Deeds Done Dirt Cheap          AC/DC    1976
# 15                        For Those About To Rock          AC/DC    1981
# 16                               Girls Got Rhythm          AC/DC       0
# 17                                 Hard As A Rock          AC/DC    1995
# 18                             Have a Drink On Me          AC/DC    1980
# 19                                    Hells Bells          AC/DC    1980
# 20                                Highway To Hell          AC/DC    1979
# 21                     It's A Long Way To The Top          AC/DC    1975
# 22                                      Jailbreak          AC/DC    1984
# 23                              Let There Be Rock          AC/DC    1977
# 24                                Let's Get It Up          AC/DC       0
# 25                                      Live Wire          AC/DC       0
# 26                                     Moneytalks          AC/DC       0
# 27                                  Night Prowler          AC/DC    1979
# 28            Rock and Roll Ain't Noise Pollution          AC/DC    1980
# 29                                Shoot To Thrill          AC/DC       0
# ...                                           ...            ...     ...
# 2200                      Owner of a Lonely Heart            Yes    1983
# 2201                                   Roundabout            Yes    1971
# 2202                             Starship Trooper            Yes    1971
# 2203                            Wonderous Stories            Yes       0
# 2204                         Yours Is No Disgrace            Yes    1971
# 2205                        Tell Me What You Want          Zebra       0
# 2206                        Who's Behind The Door          Zebra       0
# 2207                           Time of the Season        Zombies    1968
# 2208                    A Fool for Your Stockings         ZZ Top       0
# 2209             Arrested For Driving While Blind         ZZ Top    1976
# 2210                 Beer Drinkers & Hell Raisers         ZZ Top    1973
# 2211                             Cheap Sunglasses         ZZ Top    1980
# 2212                         Gimme All Your Lovin         ZZ Top    1983
# 2213                        Got Me Under Pressure         ZZ Top    1983
# 2214                            Heard It On the X         ZZ Top    1975
# 2215                                  I Thank You         ZZ Top       0
# 2216                      I'm Bad, I'm Nationwide         ZZ Top       0
# 2217                      Jesus Just Left Chicago         ZZ Top    1973
# 2218                                Just Got Paid         ZZ Top       0
# 2219                                    La Grange         ZZ Top    1973
# 2220                                         Legs         ZZ Top    1983
# 2221                     My Head's In Mississippi         ZZ Top       0
# 2222                           Party On The Patio         ZZ Top       0
# 2223                               Pearl Necklace         ZZ Top    1981
# 2224                            Sharp Dressed Man         ZZ Top    1983
# 2225                      She Loves My Automobile         ZZ Top       0
# 2226                            Tube Snake Boogie         ZZ Top    1981
# 2227                                         Tush         ZZ Top    1975
# 2228                                   TV Dinners         ZZ Top    1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO         ZZ Top    1973
#
#                                                Combined
# 0                       Caught Up in You by .38 Special
# 1                           Fantasy Girl by .38 Special
# 2                        Hold On Loosely by .38 Special
# 3                 Rockin' Into the Night by .38 Special
# 4                             Art For Arts Sake by 10cc
# 5                            Kryptonite by 3 Doors Down
# 6                                 Loser by 3 Doors Down
# 7                         When I'm Gone by 3 Doors Down
# 8                           What's Up? by 4 Non Blondes
# 9                                    Take On Me by a-ha
# 10                       Baby, Please Don't Go by AC/DC
# 11                               Back In Black by AC/DC
# 12                                     Big Gun by AC/DC
# 13                      CAN'T STOP ROCK'N'ROLL by AC/DC
# 14                 Dirty Deeds Done Dirt Cheap by AC/DC
# 15                     For Those About To Rock by AC/DC
# 16                            Girls Got Rhythm by AC/DC
# 17                              Hard As A Rock by AC/DC
# 18                          Have a Drink On Me by AC/DC
# 19                                 Hells Bells by AC/DC
# 20                             Highway To Hell by AC/DC
# 21                  It's A Long Way To The Top by AC/DC
# 22                                   Jailbreak by AC/DC
# 23                           Let There Be Rock by AC/DC
# 24                             Let's Get It Up by AC/DC
# 25                                   Live Wire by AC/DC
# 26                                  Moneytalks by AC/DC
# 27                               Night Prowler by AC/DC
# 28         Rock and Roll Ain't Noise Pollution by AC/DC
# 29                             Shoot To Thrill by AC/DC
# ...                                                 ...
# 2200                     Owner of a Lonely Heart by Yes
# 2201                                  Roundabout by Yes
# 2202                            Starship Trooper by Yes
# 2203                           Wonderous Stories by Yes
# 2204                        Yours Is No Disgrace by Yes
# 2205                     Tell Me What You Want by Zebra
# 2206                     Who's Behind The Door by Zebra
# 2207                      Time of the Season by Zombies
# 2208                A Fool for Your Stockings by ZZ Top
# 2209         Arrested For Driving While Blind by ZZ Top
# 2210             Beer Drinkers & Hell Raisers by ZZ Top
# 2211                         Cheap Sunglasses by ZZ Top
# 2212                     Gimme All Your Lovin by ZZ Top
# 2213                    Got Me Under Pressure by ZZ Top
# 2214                        Heard It On the X by ZZ Top
# 2215                              I Thank You by ZZ Top
# 2216                  I'm Bad, I'm Nationwide by ZZ Top
# 2217                  Jesus Just Left Chicago by ZZ Top
# 2218                            Just Got Paid by ZZ Top
# 2219                                La Grange by ZZ Top
# 2220                                     Legs by ZZ Top
# 2221                 My Head's In Mississippi by ZZ Top
# 2222                       Party On The Patio by ZZ Top
# 2223                           Pearl Necklace by ZZ Top
# 2224                        Sharp Dressed Man by ZZ Top
# 2225                  She Loves My Automobile by ZZ Top
# 2226                        Tube Snake Boogie by ZZ Top
# 2227                                     Tush by ZZ Top
# 2228                               TV Dinners by ZZ Top
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...
#
# [2230 rows x 4 columns]

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
# A:
rock.Release.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:
rock.dtypes

#Release should be an int64 and not a string!
# Out:
# Song         object
# Artist       object
# Release      object
# Combined     object
# First         int64
# Year          int64
# Playcount     int64
# F*G           int64
# dtype: object

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
# A:
i = 0
empty = []
for year in rock["Release"]:
    if type(year) == str:
        empty.append(i)
    i += 1
len(empty)
# Out:
# 1653

# %%
rock["Release"].unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
mask = (rock.Release == "Release Year") | (rock.Release == "SONGFACTS.COM")

rock.loc[mask, "Release"] = 0
#writes over the row where release is "SONGFACTS.COM" with the value 0
# Out:
# Series([], Name: Release, dtype: object)

# %%
#rock.isnull().sum() > 0

#rock.loc[:, rock.isnull().sum() > 0 ]
# Out:
# Song         False
# Artist       False
# Release      False
# Combined     False
# First        False
# Year         False
# Playcount    False
# F*G          False
# dtype: bool

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
# A:

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
# A:

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A:
rock["Release"].describe()
# Out:
# count     2230
# unique      56
# top          0
# freq       578
# Name: Release, dtype: int64

# %%
max(rock["Release"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-8b45a7120230> in <module>()
# ----> 1 max(rock["Release"])
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %%
# A:
rock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song         2230 non-null object
# Artist       2230 non-null object
# Release      2230 non-null object
# Combined     2230 non-null object
# First        2230 non-null int64
# Year         2230 non-null int64
# Playcount    2230 non-null int64
# F*G          2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %%
#the .astype() method allows us to loop thru an entire column and change its type
    #i.e. np.int16 for 16-bit integer

rock["Release"] = rock["Release"].astype(np.int16)
#also note that for large datasets, the bit-size of your entires really matter alot 

#8-bit is too small for release year since 2 ** 8 = 256 
#16-bit works well for release date since release years contain 4 values 
#64-bit is overkill for this situation

# %%
rock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song         2230 non-null object
# Artist       2230 non-null object
# Release      2230 non-null int16
# Combined     2230 non-null object
# First        2230 non-null int64
# Year         2230 non-null int64
# Playcount    2230 non-null int64
# F*G          2230 non-null int64
# dtypes: int16(1), int64(4), object(3)
# memory usage: 126.4+ KB

# %%
rock["Release"].describe()
# Out:
# count    2230.000000
# mean     1465.331390
# std       867.196161
# min         0.000000
# 25%         0.000000
# 50%      1973.000000
# 75%      1981.000000
# max      2014.000000
# Name: Release, dtype: float64

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A:
def print_info(row):
    return row["Song"], row["Artist"] , row["Release"] < 1970

print_info(rock.loc[4,:])
# Out:
# ('Art For Arts Sake', '10cc', False)

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.
